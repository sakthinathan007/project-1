# %% [markdown]
# ### SMART SCHOOL LEARNING MANAGEMENT SYSTEM

# %%
from admission_model import admission_model

# %%
from performance_prediction1 import performance_model

# %%
from timetable_generation1 import generate_timetable

# %%
print("SMART SCHOOL LEARNING MANAGEMENT SYSTEM")

print("\n----- Admission Prediction -----")
admission_model()

print("\n----- Student Performance Prediction -----")
performance_model()

print("\n----- Automatic Timetable Generation -----")
generate_timetable()
# Out:
# SMART SCHOOL LEARNING MANAGEMENT SYSTEM
#
# ----- Admission Prediction -----
# Admission model running...
#
# Enter Student Details
# Entrance Exam Score:  85
# School Marks:  90
# Distance from School (km):  5
# Scholarship (1=Yes, 0=No):  1
# Prediction: Student will JOIN the school
#
# ----- Student Performance Prediction -----
# Performance prediction running...
#
# Enter Student Details
# C:\Users\ravis\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Attendance (%):  82
# Internal Marks:  65
# Assignment Marks:  70
# Prediction: Student will PASS
#
# ----- Automatic Timetable Generation -----
# Timetable generation running...
#
# Generated Timetable
#
#           Time Class  Subject   Teacher Room
# 0   9:00-10:00   10A  English  Mr Kumar  101
# 1  10:00-11:00   10A  English    Mr Raj  103
# 2  11:00-12:00   10A     Math    Mr Raj  103
# ...
