# %%
# %run run_system.py
# Out:
#   ╔══════════════════════════════════════════════╗
#   ║   REAL-TIME TRAFFIC FORECASTING SYSTEM      ║
#   ║   Loaded from: traffic_dataset.csv          ║
#   ╚══════════════════════════════════════════════╝
#
#   Dataset loaded: 10 locations found
#
#   Available locations in your dataset:
#   #    Location ID        Name                   City         Congestion
#   ──────────────────────────────────────────────────────────────────────
#   1    mg_road            MG Road                Bengaluru    82%
#   2    anna_nagar         Anna Nagar             Chennai      54%
#   3    t_nagar            T. Nagar               Chennai      94%
#   4    ecr_highway        ECR Highway            Chennai      38%
#   5    silk_board         Silk Board Junction    Bengaluru    98%
#   6    koyambedu          Koyambedu Junction     Chennai      88%
#   7    besant_nagar       Besant Nagar           Chennai      46%
#   8    whitefield         Whitefield             Bengaluru    68%
# ...
